# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at: /device:GPU:0

# %% [markdown]
# # 1. Import Modules

# %%
import numpy as np
import matplotlib.pylab as plt
import itertools
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score

# import keras
# from keras import backend as K
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, model_from_json
# from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D, SeparableConv2D

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
X = np.load('/content/drive/MyDrive/b_cancer/X.npy') # images
Y = np.load('/content/drive/MyDrive/b_cancer/Y.npy') # labels associated to images (0 = no IDC, 1 = IDC)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
# 0과 1 사이로 스케일 조정

X_train = X_train / 255.0
# X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
y_train = to_categorical(y_train, num_classes = 2)
# y_val = to_categorical(y_val, num_classes = 2)
y_test = to_categorical(y_test, num_classes = 2)

# %% [markdown]
# #### 클래스 가중치 계산

# %%
classTotals = y_train.sum(axis=0)
classTotals
# Out:
# array([1934., 1948.], dtype=float32)

# %%
# loop over all classes and calculate the class weight
classWeight = dict()

for i in range(0, len(classTotals)):
  classWeight[i] = classTotals.max() / classTotals[i]

classWeight
# Out:
# {0: 1.0072389, 1: 1.0}

# %% [markdown]
# *(4. Data Augmentation)*

# %%
# # initialize the training data augmentation object
# trainAug = ImageDataGenerator(
#     	rotation_range=20,
#       zoom_range=0.05,
#       width_shift_range=0.1,
#       height_shift_range=0.1,
#       shear_range=0.05,
#       horizontal_flip=True,
#       vertical_flip=True,
#       fill_mode="nearest")

# # initialize the validation (and testing) data augmentation object
# valAug = ImageDataGenerator()

# %%
# BS = 32

# # initialize the training generator
# trainGen = trainAug.flow(X_train, batch_size=BS)

# # initialize the validation generator
# valGen = valAug.flow(X_val, batch_size=BS)

# # initialize the testing generator
# testGen = valAug.flow(X_test, batch_size=BS)

# %% [markdown]
# # 3. 모델 컴파일하고 학습 시작

# %% [markdown]
# ### 1) SeperableConv2D 대신 Conv2D 사용

# %%
with tf.device('/device:GPU:0'):
  cancernet = Sequential()
  inputShape = (50, 50, 3)

  # CONV => RELU => POOL
  cancernet.add(Conv2D(32, (3, 3), padding="same",
    input_shape=inputShape))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 2
  cancernet.add(Conv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 3
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # first (and only) set of FC => RELU layers
  cancernet.add(Flatten())
  cancernet.add(Dense(256))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Dropout(0.5))

  # softmax classifier
  cancernet.add(Dense(2))
  cancernet.add(Activation("softmax"))

# %%
with tf.device('/device:GPU:0'):
  NUM_EPOCHS = 40
  INIT_LR = 1e-2
  BS = 32
  
  opt = Adagrad(learning_rate=INIT_LR, decay=INIT_LR / NUM_EPOCHS)
  cancernet.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

  H = cancernet.fit(X_train, y_train, 
                validation_data = (X_test, y_test),
                class_weight = classWeight,
                epochs = NUM_EPOCHS)
# Out:
# Epoch 1/40
# 122/122 [==============================] - 15s 19ms/step - loss: 0.6999 - accuracy: 0.7290 - val_loss: 1.2577 - val_accuracy: 0.5045
# Epoch 2/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.5898 - accuracy: 0.7643 - val_loss: 1.4942 - val_accuracy: 0.5045
# Epoch 3/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.5477 - accuracy: 0.7751 - val_loss: 0.9215 - val_accuracy: 0.5171
# Epoch 4/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.5489 - accuracy: 0.7694 - val_loss: 0.9684 - val_accuracy: 0.5099
# Epoch 5/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.5225 - accuracy: 0.7772 - val_loss: 0.9513 - val_accuracy: 0.5273
# Epoch 6/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.5019 - accuracy: 0.7846 - val_loss: 0.7107 - val_accuracy: 0.6601
# Epoch 7/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.5037 - accuracy: 0.7870 - val_loss: 0.6016 - val_accuracy: 0.7333
# Epoch 8/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4870 - accuracy: 0.7960 - val_loss: 0.5743 - val_accuracy: 0.7387
# Epoch 9/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4796 - accuracy: 0.7862 - val_loss: 0.5285 - val_accuracy: 0.7832
# Epoch 10/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4851 - accuracy: 0.7888 - val_loss: 0.6359 - val_accuracy: 0.7321
# Epoch 11/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4665 - accuracy: 0.8032 - val_loss: 0.5156 - val_accuracy: 0.7694
# Epoch 12/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4608 - accuracy: 0.8050 - val_loss: 0.5129 - val_accuracy: 0.7784
# Epoch 13/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4519 - accuracy: 0.8055 - val_loss: 0.6258 - val_accuracy: 0.7477
# Epoch 14/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4551 - accuracy: 0.8050 - val_loss: 0.5365 - val_accuracy: 0.7568
# Epoch 15/40
# 122/122 [==============================] - 2s 14ms/step - loss: 0.4504 - accuracy: 0.8089 - val_loss: 0.5840 - val_accuracy: 0.7562
# Epoch 16/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4428 - accuracy: 0.8104 - val_loss: 0.5481 - val_accuracy: 0.7694
# Epoch 17/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4337 - accuracy: 0.8112 - val_loss: 0.5586 - val_accuracy: 0.7772
# Epoch 18/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4345 - accuracy: 0.8125 - val_loss: 0.5746 - val_accuracy: 0.7477
# Epoch 19/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4279 - accuracy: 0.8171 - val_loss: 0.4917 - val_accuracy: 0.7862
# Epoch 20/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4208 - accuracy: 0.8161 - val_loss: 0.5924 - val_accuracy: 0.7333
# Epoch 21/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4209 - accuracy: 0.8189 - val_loss: 0.4865 - val_accuracy: 0.7808
# Epoch 22/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4255 - accuracy: 0.8174 - val_loss: 0.5961 - val_accuracy: 0.7375
# Epoch 23/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4150 - accuracy: 0.8217 - val_loss: 0.4904 - val_accuracy: 0.7796
# Epoch 24/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4122 - accuracy: 0.8243 - val_loss: 0.6525 - val_accuracy: 0.7339
# Epoch 25/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.4122 - accuracy: 0.8241 - val_loss: 0.6760 - val_accuracy: 0.7459
# Epoch 26/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.4082 - accuracy: 0.8248 - val_loss: 0.5091 - val_accuracy: 0.7688
# Epoch 27/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.3891 - accuracy: 0.8382 - val_loss: 0.6581 - val_accuracy: 0.7435
# Epoch 28/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3862 - accuracy: 0.8331 - val_loss: 0.6083 - val_accuracy: 0.7526
# Epoch 29/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3879 - accuracy: 0.8369 - val_loss: 0.6055 - val_accuracy: 0.7724
# Epoch 30/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.3832 - accuracy: 0.8359 - val_loss: 0.4992 - val_accuracy: 0.7838
# Epoch 31/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3675 - accuracy: 0.8426 - val_loss: 0.5029 - val_accuracy: 0.7862
# Epoch 32/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3778 - accuracy: 0.8426 - val_loss: 0.5270 - val_accuracy: 0.7700
# Epoch 33/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.3644 - accuracy: 0.8501 - val_loss: 0.8559 - val_accuracy: 0.7219
# Epoch 34/40
# 122/122 [==============================] - 1s 12ms/step - loss: 0.3641 - accuracy: 0.8496 - val_loss: 0.6181 - val_accuracy: 0.7495
# Epoch 35/40
# 122/122 [==============================] - 2s 12ms/step - loss: 0.3578 - accuracy: 0.8509 - val_loss: 0.5204 - val_accuracy: 0.7814
# Epoch 36/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3568 - accuracy: 0.8490 - val_loss: 0.5638 - val_accuracy: 0.7730
# Epoch 37/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3634 - accuracy: 0.8449 - val_loss: 0.5094 - val_accuracy: 0.7772
# Epoch 38/40
# 122/122 [==============================] - 2s 13ms/step - loss: 0.3564 - accuracy: 0.8521 - val_loss: 0.7168 - val_accuracy: 0.7363
# Epoch 39/40
# 122/122 [==============================] - 2s 12ms/step - loss: 0.3499 - accuracy: 0.8552 - val_loss: 0.5783 - val_accuracy: 0.7796
# Epoch 40/40
# 122/122 [==============================] - 2s 12ms/step - loss: 0.3425 - accuracy: 0.8604 - val_loss: 0.5249 - val_accuracy: 0.7742

# %%
history_dict = H.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(acc)+1)

plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuary')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ### 2) SeperableConv2D 사용하되 네트워크 크기를 더 크게

# %%
with tf.device('/device:GPU:0'):
  cancernet = Sequential()
  inputShape = (50, 50, 3)

  # CONV => RELU => POOL
  cancernet.add(SeparableConv2D(32, (3, 3), padding="same",
    input_shape=inputShape))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 2
  cancernet.add(SeparableConv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(SeparableConv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 3
  cancernet.add(SeparableConv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(SeparableConv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(SeparableConv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 4
  cancernet.add(SeparableConv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(SeparableConv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(SeparableConv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(SeparableConv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))

  # first (and only) set of FC => RELU layers
  cancernet.add(Flatten())
  cancernet.add(Dense(256))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Dropout(0.5))

  # softmax classifier
  cancernet.add(Dense(2))
  cancernet.add(Activation("softmax"))

# %%
with tf.device('/device:GPU:0'):
  NUM_EPOCHS = 40
  INIT_LR = 1e-2
  BS = 32
  
  opt = Adagrad(learning_rate=INIT_LR, decay=INIT_LR / NUM_EPOCHS)
  cancernet.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

  H = cancernet.fit(X_train, y_train, 
                validation_data = (X_test, y_test),
                class_weight = classWeight,
                epochs = NUM_EPOCHS)
# Out:
# Epoch 1/40
# 122/122 [==============================] - 4s 20ms/step - loss: 0.6699 - accuracy: 0.7012 - val_loss: 0.6970 - val_accuracy: 0.5045
# Epoch 2/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.5765 - accuracy: 0.7452 - val_loss: 0.7144 - val_accuracy: 0.5045
# Epoch 3/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.5525 - accuracy: 0.7545 - val_loss: 0.7547 - val_accuracy: 0.5045
# Epoch 4/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.5388 - accuracy: 0.7553 - val_loss: 0.8014 - val_accuracy: 0.5045
# Epoch 5/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.5271 - accuracy: 0.7607 - val_loss: 0.6999 - val_accuracy: 0.5045
# Epoch 6/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.5191 - accuracy: 0.7656 - val_loss: 0.5962 - val_accuracy: 0.6955
# Epoch 7/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.5177 - accuracy: 0.7615 - val_loss: 0.6457 - val_accuracy: 0.6535
# Epoch 8/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.5068 - accuracy: 0.7658 - val_loss: 0.5367 - val_accuracy: 0.7634
# Epoch 9/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.5070 - accuracy: 0.7713 - val_loss: 0.5848 - val_accuracy: 0.7495
# Epoch 10/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4924 - accuracy: 0.7808 - val_loss: 0.5457 - val_accuracy: 0.7646
# Epoch 11/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4975 - accuracy: 0.7746 - val_loss: 0.5334 - val_accuracy: 0.7598
# Epoch 12/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4933 - accuracy: 0.7723 - val_loss: 0.5499 - val_accuracy: 0.7471
# Epoch 13/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4895 - accuracy: 0.7779 - val_loss: 0.5333 - val_accuracy: 0.7634
# Epoch 14/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4751 - accuracy: 0.7880 - val_loss: 0.5250 - val_accuracy: 0.7634
# Epoch 15/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4756 - accuracy: 0.7862 - val_loss: 0.4964 - val_accuracy: 0.7646
# Epoch 16/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4715 - accuracy: 0.7919 - val_loss: 0.5412 - val_accuracy: 0.7574
# Epoch 17/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4688 - accuracy: 0.7916 - val_loss: 0.5219 - val_accuracy: 0.7694
# Epoch 18/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4716 - accuracy: 0.7885 - val_loss: 0.5120 - val_accuracy: 0.7628
# Epoch 19/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4648 - accuracy: 0.7934 - val_loss: 0.5248 - val_accuracy: 0.7652
# Epoch 20/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4655 - accuracy: 0.7875 - val_loss: 0.4968 - val_accuracy: 0.7712
# Epoch 21/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4587 - accuracy: 0.7957 - val_loss: 0.5198 - val_accuracy: 0.7802
# Epoch 22/40
# 122/122 [==============================] - 2s 19ms/step - loss: 0.4551 - accuracy: 0.7975 - val_loss: 0.5061 - val_accuracy: 0.7628
# Epoch 23/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4558 - accuracy: 0.7978 - val_loss: 0.5509 - val_accuracy: 0.7453
# Epoch 24/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4506 - accuracy: 0.7983 - val_loss: 0.5182 - val_accuracy: 0.7544
# Epoch 25/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4474 - accuracy: 0.8019 - val_loss: 0.5738 - val_accuracy: 0.7646
# Epoch 26/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4503 - accuracy: 0.7916 - val_loss: 0.5282 - val_accuracy: 0.7646
# Epoch 27/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4435 - accuracy: 0.8024 - val_loss: 0.5189 - val_accuracy: 0.7700
# Epoch 28/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4428 - accuracy: 0.8019 - val_loss: 0.5297 - val_accuracy: 0.7634
# Epoch 29/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4436 - accuracy: 0.8040 - val_loss: 0.5254 - val_accuracy: 0.7622
# Epoch 30/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4476 - accuracy: 0.8050 - val_loss: 0.5069 - val_accuracy: 0.7676
# Epoch 31/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4437 - accuracy: 0.7978 - val_loss: 0.5061 - val_accuracy: 0.7670
# Epoch 32/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4471 - accuracy: 0.7975 - val_loss: 0.5161 - val_accuracy: 0.7748
# Epoch 33/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4388 - accuracy: 0.8022 - val_loss: 0.5105 - val_accuracy: 0.7634
# Epoch 34/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4271 - accuracy: 0.8071 - val_loss: 0.5244 - val_accuracy: 0.7616
# Epoch 35/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4304 - accuracy: 0.8045 - val_loss: 0.5373 - val_accuracy: 0.7658
# Epoch 36/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4265 - accuracy: 0.8130 - val_loss: 0.5097 - val_accuracy: 0.7622
# Epoch 37/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4325 - accuracy: 0.8042 - val_loss: 0.5089 - val_accuracy: 0.7694
# Epoch 38/40
# 122/122 [==============================] - 2s 15ms/step - loss: 0.4193 - accuracy: 0.8089 - val_loss: 0.5204 - val_accuracy: 0.7592
# Epoch 39/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4261 - accuracy: 0.8040 - val_loss: 0.5314 - val_accuracy: 0.7604
# Epoch 40/40
# 122/122 [==============================] - 2s 16ms/step - loss: 0.4190 - accuracy: 0.8122 - val_loss: 0.5293 - val_accuracy: 0.7610

# %%
history_dict = H.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(acc)+1)

plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuary')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ### 3) Conv2D 쓰고 네트워크 크게

# %%
with tf.device('/device:GPU:0'):
  cancernet = Sequential()
  inputShape = (50, 50, 3)

  # CONV => RELU => POOL
  cancernet.add(Conv2D(32, (3, 3), padding="same",
    input_shape=inputShape))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 2
  cancernet.add(Conv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(64, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 3
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(128, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # (CONV => RELU => POOL) * 4
  cancernet.add(Conv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Conv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(Conv2D(256, (3, 3), padding="same"))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(MaxPooling2D(pool_size=(2, 2)))
  cancernet.add(Dropout(0.25))

  # first (and only) set of FC => RELU layers
  cancernet.add(Flatten())
  cancernet.add(Dense(256))
  cancernet.add(Activation("relu"))
  cancernet.add(BatchNormalization())
  cancernet.add(Dropout(0.5))

  # softmax classifier
  cancernet.add(Dense(2))
  cancernet.add(Activation("softmax"))

# %%
with tf.device('/device:GPU:0'):
  NUM_EPOCHS = 40
  INIT_LR = 1e-2
  BS = 32
  
  opt = Adagrad(learning_rate=INIT_LR, decay=INIT_LR / NUM_EPOCHS)
  cancernet.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

  H = cancernet.fit(X_train, y_train, 
                validation_data = (X_test, y_test),
                class_weight = classWeight,
                epochs = NUM_EPOCHS)
# Out:
# Epoch 1/40
# 122/122 [==============================] - 4s 21ms/step - loss: 0.7076 - accuracy: 0.7076 - val_loss: 0.9220 - val_accuracy: 0.5045
# Epoch 2/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.5862 - accuracy: 0.7522 - val_loss: 0.9236 - val_accuracy: 0.5045
# Epoch 3/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.5559 - accuracy: 0.7612 - val_loss: 0.7570 - val_accuracy: 0.6246
# Epoch 4/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.5250 - accuracy: 0.7728 - val_loss: 0.9228 - val_accuracy: 0.5225
# Epoch 5/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.5260 - accuracy: 0.7782 - val_loss: 0.9328 - val_accuracy: 0.5778
# Epoch 6/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4971 - accuracy: 0.7831 - val_loss: 0.6783 - val_accuracy: 0.6354
# Epoch 7/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4937 - accuracy: 0.7826 - val_loss: 0.9379 - val_accuracy: 0.6198
# Epoch 8/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4858 - accuracy: 0.7862 - val_loss: 0.6341 - val_accuracy: 0.7069
# Epoch 9/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4751 - accuracy: 0.7916 - val_loss: 0.5815 - val_accuracy: 0.7784
# Epoch 10/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4657 - accuracy: 0.7929 - val_loss: 0.5964 - val_accuracy: 0.7706
# Epoch 11/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4713 - accuracy: 0.7965 - val_loss: 0.7560 - val_accuracy: 0.7183
# Epoch 12/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4602 - accuracy: 0.7975 - val_loss: 0.6243 - val_accuracy: 0.7399
# Epoch 13/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4477 - accuracy: 0.8065 - val_loss: 0.8777 - val_accuracy: 0.7075
# Epoch 14/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4489 - accuracy: 0.8058 - val_loss: 0.4828 - val_accuracy: 0.7946
# Epoch 15/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4457 - accuracy: 0.8022 - val_loss: 0.5091 - val_accuracy: 0.7718
# Epoch 16/40
# 122/122 [==============================] - 2s 18ms/step - loss: 0.4364 - accuracy: 0.7978 - val_loss: 0.5110 - val_accuracy: 0.7652
# Epoch 17/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4365 - accuracy: 0.8042 - val_loss: 0.5104 - val_accuracy: 0.7784
# Epoch 18/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4313 - accuracy: 0.8065 - val_loss: 0.6886 - val_accuracy: 0.7556
# Epoch 19/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4198 - accuracy: 0.8135 - val_loss: 0.6745 - val_accuracy: 0.7213
# Epoch 20/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4233 - accuracy: 0.8127 - val_loss: 0.5934 - val_accuracy: 0.7754
# Epoch 21/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4110 - accuracy: 0.8158 - val_loss: 0.5936 - val_accuracy: 0.7423
# Epoch 22/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4106 - accuracy: 0.8202 - val_loss: 0.5285 - val_accuracy: 0.7610
# Epoch 23/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.4027 - accuracy: 0.8199 - val_loss: 0.5620 - val_accuracy: 0.7538
# Epoch 24/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3968 - accuracy: 0.8251 - val_loss: 0.6560 - val_accuracy: 0.7405
# Epoch 25/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3950 - accuracy: 0.8362 - val_loss: 0.6223 - val_accuracy: 0.7339
# Epoch 26/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3858 - accuracy: 0.8344 - val_loss: 0.5254 - val_accuracy: 0.7874
# Epoch 27/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3855 - accuracy: 0.8305 - val_loss: 0.5946 - val_accuracy: 0.7508
# Epoch 28/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3865 - accuracy: 0.8333 - val_loss: 0.5133 - val_accuracy: 0.7838
# Epoch 29/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3743 - accuracy: 0.8357 - val_loss: 0.5707 - val_accuracy: 0.7423
# Epoch 30/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3609 - accuracy: 0.8442 - val_loss: 0.5561 - val_accuracy: 0.7874
# Epoch 31/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3660 - accuracy: 0.8408 - val_loss: 0.7203 - val_accuracy: 0.7153
# Epoch 32/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3633 - accuracy: 0.8411 - val_loss: 0.5907 - val_accuracy: 0.7730
# Epoch 33/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3543 - accuracy: 0.8478 - val_loss: 0.6802 - val_accuracy: 0.7652
# Epoch 34/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3415 - accuracy: 0.8542 - val_loss: 0.5549 - val_accuracy: 0.7423
# Epoch 35/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3393 - accuracy: 0.8532 - val_loss: 0.7049 - val_accuracy: 0.6907
# Epoch 36/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3365 - accuracy: 0.8498 - val_loss: 0.6194 - val_accuracy: 0.7526
# Epoch 37/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3322 - accuracy: 0.8570 - val_loss: 0.6625 - val_accuracy: 0.7532
# Epoch 38/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3173 - accuracy: 0.8627 - val_loss: 0.6310 - val_accuracy: 0.7489
# Epoch 39/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3208 - accuracy: 0.8645 - val_loss: 0.6042 - val_accuracy: 0.7646
# Epoch 40/40
# 122/122 [==============================] - 2s 17ms/step - loss: 0.3008 - accuracy: 0.8725 - val_loss: 0.5828 - val_accuracy: 0.7766

# %%
history_dict = H.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(acc)+1)

plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuary')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
